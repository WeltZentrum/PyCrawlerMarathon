# %% [markdown]
# # 動態網頁爬蟲 - API Request
#
# * 了解 API Request 用於動態網頁爬蟲的原理
# * 能夠使用 API Request 撰寫動態網頁爬蟲

# %% [markdown]
# ## 作業目標
#
# * 根據範例的教學，去找出 Dcard 中呼叫的 API 當中，有一個跟「取得所有看板」是哪一個？並且利用 Requests 呼叫。

# %% [markdown]
# * 請附上截圖：_______
#
# ![]()

# %%
from IPython.display import Image
Image("D20.png" , width='800', height='800')

# %%
Image("D20_1.png" , width='800', height='800')

# %%
'''
Your Code
'''
import requests
import json

r = requests.get('https://www.dcard.tw/service/api/v2/forums?nsfw=true')
json.loads(r.text)
# Out:
# [{'alias': 'midnightlab',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-14T19:15:15.698Z',
#   'description': '午夜實驗室10/6、10/7即將在華山登場！這裏提供大家交流活動資訊與討論，請大家要遵守 Dcard 板規喔！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'id': '7f125e07-4460-4ea5-80b5-33f0e9aafa0c',
#   'ignorePost': False,
#   'invisible': True,
#   'ipCountryCondition': {},
#   'isSchool': False,
#   'limitCountries': [],
#   'limitStage': 0,
#   'mediaThreshold': {},
#   'name': '午夜實驗室',
#   'nsfw': False,
#   'postCount': {'last30Days': 1},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': [],
#   'subscribed': False,
#   'subscriptionCount': 1846,
#   'titlePlaceholder': '',
#   'topics': ['午夜實驗室'],
#   'updatedAt': '2018-11-05T03:24:32.914Z'},
#  {'alias': 'timecapsule',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-14T20:15:15.698Z',
#   'description': '寫下你的新年新希望，一年後將收到「時光膠囊」，幫助你檢視這一年達成了多少目標，實現了多少願望！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'id': 'c0ed3f99-ed1c-49a8-b413-ed5e925aafe4',
#   'ignorePost': True,
#   'invisible': True,
#   'ipCountryCondition': {},
#   'isSchool': False,
#   'limitCountries': [],
#   'limitStage': 0,
#   'mediaThreshold': {},
#   'name': '時光膠囊',
#   'nsfw': False,
#   'postCount': {'last30Days': 6},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': [],
#   'subscribed': False,
#   'subscriptionCount': 3159,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2020-01-02T02:23:04.836Z'},
#  {'alias': 'mother',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-14T22:15:15.699Z',
#   'description': 'Dcard 母親節限定板，告訴媽媽我愛妳！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'id': 'cc2164ae-88cd-466d-b11b-19e4b1f6f78c',
#   'ignorePost': False,
#   'invisible': True,
#   'ipCountryCondition': {},
#   'isSchool': False,
#   'limitCountries': [],
#   'limitStage': 0,
#   'mediaThreshold': {},
#   'name': '母親節',
#   'nsfw': False,
#   'postCount': {'last30Days': 0},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': [],
#   'subscribed': False,
#   'subscriptionCount': 428,
#   'titlePlaceholder': '',
#   'topics': ['我是媽寶我驕傲',
#    '曬媽媽',
#    '母親節蛋糕',
#    '康乃馨',
#    '母親節花束',
#    '我愛媽媽',
#    '母親節禮物',
#    '媽媽我愛你',
#    '媽媽',
#    '母親節大餐',
#    '母親節檔期'],
#   'updatedAt': '2018-05-15T08:04:10.308Z'},
#  {'alias': 'merryxmas',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-17T00:11:15.742Z',
#   'description': '期間限定開啟！只要是和聖誕節有關的事情，或是和「禮物」有關的東西通通都來分享吧！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/7b5b4c6c-ee5b-4903-a27f-e772de58f078/orig.jpeg',
#    'width': 1800},
#   'id': '11e8d941-0aad-4960-8348-b27c36270fd1',
#   'ignorePost': False,
#   'invisible': True,
#   'ipCountryCondition': {},
#   'isSchool': False,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/1d36a792-6e4a-40be-8656-89a0b5973f6c/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '聖誕CiaoCiao',
#   'nsfw': False,
#   'postCount': {'last30Days': 1},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': [],
#   'subscribed': False,
#   'subscriptionCount': 18351,
#   'titlePlaceholder': '',
#   'topics': ['Dcard聖誕列車', '交換禮物', '聖誕禮物', '聖誕卡片', '聖誕舞會', '聖誕樹', '聖誕節'],
#   'updatedAt': '2020-01-06T03:28:44.981Z'},
#  {'alias': 'father',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-17T00:12:15.742Z',
#   'description': 'Dcard 父親節特輯，上傳爸爸帥照，寫下真摯文字，一起謝謝我們心中的 「鋼鐵人老爸」。',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'id': '8d5cabde-d0df-479f-8ab7-153209317537',
#   'ignorePost': False,
#   'invisible': True,
#   'ipCountryCondition': {},
#   'isSchool': False,
#   'limitCountries': [],
#   'limitStage': 0,
#   'mediaThreshold': {},
#   'name': '父親節',
#   'nsfw': False,
#   'postCount': {'last30Days': 0},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': [],
#   'subscribed': False,
#   'subscriptionCount': 408,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2017-01-01T10:36:38.235Z'},
#  {'alias': '5anniversary',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-18T07:20:35.140Z',
#   'description': '五週年徵文活動限定板，僅供活動徵文、討論，發文前請先閱讀置頂喔！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'id': '460a5276-0480-4af1-86df-14b3040cab08',
#   'ignorePost': False,
#   'invisible': True,
#   'ipCountryCondition': {},
#   'isSchool': False,
#   'limitCountries': [],
#   'limitStage': 0,
#   'mediaThreshold': {},
#   'name': '五週年紀念',
#   'nsfw': False,
#   'postCount': {'last30Days': 0},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': [],
#   'subscribed': False,
#   'subscriptionCount': 5825,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2018-04-18T07:16:27.550Z'},
#  {'alias': 'bugreport',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-18T07:20:35.140Z',
#   'description': '臨時回報版本問題',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'id': '4dd9f69b-9b33-4ba0-9cec-887d8c5091e4',
#   'ignorePost': True,
#   'invisible': True,
#   'ipCountryCondition': {},
#   'isSchool': False,
#   'limitCountries': [],
#   'limitStage': 0,
#   'mediaThreshold': {},
#   'name': '臨時回報',
#   'nsfw': False,
#   'postCount': {'last30Days': 1},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': [],
#   'subscribed': False,
#   'subscriptionCount': 17,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2017-06-18T03:31:45.331Z'},
#  {'alias': 'ntu',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-19T08:15:15.752Z',
#   'description': '臺灣大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/cf164bf7-5918-4b53-956e-93632d033b14/orig.jpeg',
#    'width': 1800},
#   'id': '3c91f2b0-6374-4467-b557-2e5383680afb',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/9808ed78-e150-47bb-847f-70eab4b55470/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '臺灣大學',
#   'nsfw': False,
#   'postCount': {'last30Days': 458},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 15102,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-09-26T10:21:32.105Z'},
#  {'alias': 'nccu',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-19T09:15:15.753Z',
#   'description': '政治大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/c80ae1a6-45d0-44e7-b8e5-539cd3a88043/orig.jpeg',
#    'width': 1800},
#   'id': 'caf9487a-1994-494d-81f2-7950438e7bef',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/0af62c52-7fdd-4055-9f4c-c91b00ea856a/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '政治大學',
#   'nsfw': False,
#   'postCount': {'last30Days': 566},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 10635,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-09-26T10:23:26.327Z'},
#  {'alias': 'nctu',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-19T10:15:15.755Z',
#   'description': '交通大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/37208085-bffc-4a75-a17c-7a2b358515ef/orig.jpeg',
#    'width': 1800},
#   'id': '204997a1-c63d-4dc4-965e-9f018e452d1d',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/b6ef12ed-e127-41db-a3cd-4f9a518eaefa/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '交通大學',
#   'nsfw': False,
#   'postCount': {'last30Days': 75},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 6041,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-09-26T10:24:19.700Z'},
#  {'alias': 'tku',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-19T11:15:15.756Z',
#   'description': '淡江大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/bc6f4ea2-8698-4f85-8656-3ca6a93e0bea/orig.jpeg',
#    'width': 1800},
#   'id': '5120400e-e5e6-4676-a1b8-75a13625ecea',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/176586b3-0d17-4e5f-89c9-e3c2e0d52ea2/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '淡江大學',
#   'nsfw': False,
#   'postCount': {'last30Days': 630},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 15227,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-09-26T10:22:28.593Z'},
#  {'alias': 'ndhu',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-19T12:15:15.758Z',
#   'description': '東華大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/1517a9b4-f01c-4cc7-b2bb-3224f87cddf7/orig.jpeg',
#    'width': 1800},
#   'id': 'a8a2712f-80de-40c6-971f-c7bbb77716fe',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/32a86221-9082-4dfe-9c3d-27125e361df3/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '東華大學',
#   'nsfw': False,
#   'postCount': {'last30Days': 205},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 6058,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-09-26T10:23:53.148Z'},
#  {'alias': 'ncku',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-19T13:15:15.759Z',
#   'description': '成功大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/313d8179-6adb-4d87-a0fc-8c97fd9f14bf/orig.jpeg',
#    'width': 1800},
#   'id': 'abc4fa45-a456-49c6-8948-8981ad0b0f97',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/7812ed61-f3ff-4e62-bbb4-85489610d513/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '成功大學',
#   'nsfw': False,
#   'postCount': {'last30Days': 939},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 14687,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-09-26T10:24:17.980Z'},
#  {'alias': 'ntut',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-19T14:15:15.761Z',
#   'description': '北科大板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/ad6ab485-9ad7-4872-84b0-00a967940d1b/orig.jpeg',
#    'width': 1800},
#   'id': 'b6634fbb-b96a-41c6-82e1-80c18ed23dec',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/dc2aafc4-9004-455d-ba1f-a6eb5a6375c6/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '北科大',
#   'nsfw': False,
#   'postCount': {'last30Days': 95},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 5781,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-09-26T10:24:31.834Z'},
#  {'alias': 'fju',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-19T15:15:15.762Z',
#   'description': '輔仁大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/aeb20423-4edc-4832-b0f4-4d16236ee491/orig.jpeg',
#    'width': 1800},
#   'id': 'a62a724b-4fdd-4044-b6d3-19483aa7f0df',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/65316159-38dd-4fc4-bac8-03833d2530fb/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '輔仁大學',
#   'nsfw': False,
#   'postCount': {'last30Days': 449},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 14603,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-09-26T10:21:22.422Z'},
#  {'alias': 'ntnu',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-19T16:15:15.764Z',
#   'description': '師範大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/7d5039ea-54c1-4515-96ce-6d4bfcb2aa96/orig.jpeg',
#    'width': 1800},
#   'id': '934ab7f8-a550-4b6a-b97c-44fc63a3345e',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/6d409cfc-8310-4975-a38e-389940f1ab88/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '師範大學',
#   'nsfw': False,
#   'postCount': {'last30Days': 119},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 5985,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-09-26T10:23:18.996Z'},
#  {'alias': 'nknu',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-19T17:15:15.766Z',
#   'description': '高雄師範大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/c855878f-7855-451e-8db4-c69ce127d989/orig.jpeg',
#    'width': 1800},
#   'id': 'd2122f4e-d1b2-423a-8f68-1342906df9e9',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/73e7a308-c8a5-439a-978d-a58b4b08dc8c/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '高雄師範大學',
#   'nsfw': False,
#   'postCount': {'last30Days': 192},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 2500,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-09-26T10:23:05.486Z'},
#  {'alias': 'ncue',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-19T18:15:15.767Z',
#   'description': '彰化師範大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/326bf514-f456-4c58-96aa-a311761862c9/orig.jpeg',
#    'width': 1800},
#   'id': '51a48caf-bfd4-4c12-979e-c55962856a81',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/12e4f148-af86-440e-b2f0-4e7cb975fdd5/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '彰化師範大學',
#   'nsfw': False,
#   'postCount': {'last30Days': 151},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 3870,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-09-26T10:21:57.451Z'},
#  {'alias': 'ncu',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-19T19:15:15.769Z',
#   'description': '中央大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/c477af20-4885-4183-898f-fef172a902da/orig.jpeg',
#    'width': 1800},
#   'id': '89e7bb6b-e15f-4168-add7-0b498e335ce7',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/61e8d725-fd66-4dc0-98df-e4b3d02cfbaf/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '中央大學',
#   'nsfw': False,
#   'postCount': {'last30Days': 256},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 6821,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-09-26T10:25:08.499Z'},
#  {'alias': 'fcu',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-19T20:15:15.770Z',
#   'description': '逢甲大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/843cb1d1-5a08-4cae-9361-283b8e95c8d5/orig.jpeg',
#    'width': 1800},
#   'id': '6f72a221-b46c-4f1e-9d82-26378d407608',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/c161ea54-618a-49eb-9710-fefffc7f6c33/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '逢甲大學',
#   'nsfw': False,
#   'postCount': {'last30Days': 484},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 14789,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-09-26T10:22:25.879Z'},
#  {'alias': 'nthu',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-19T21:15:15.772Z',
#   'description': '清華大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/124c6e6e-7513-4454-9f1d-eef5cff943b4/orig.jpeg',
#    'width': 1800},
#   'id': 'e45851be-ad1b-4580-aa92-fe3e6e6fcd7e',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/2ca1c8d0-d620-418b-8f03-6a21223d6963/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '清華大學',
#   'nsfw': False,
#   'postCount': {'last30Days': 182},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 6985,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-09-26T10:22:27.377Z'},
#  {'alias': 'ncnu',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-19T22:15:15.773Z',
#   'description': '暨南大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/27a6693a-41a3-426a-94ce-b8e835a2bd80/orig.jpeg',
#    'width': 1800},
#   'id': '921374a2-1d49-491f-968f-87f187d6928e',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/a915dad1-a1cd-4a35-8198-bab82ed124f4/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '暨南大學',
#   'nsfw': False,
#   'postCount': {'last30Days': 72},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 3210,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-09-26T10:21:51.508Z'},
#  {'alias': 'thu',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-19T23:15:15.775Z',
#   'description': '東海大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/6749fe85-9287-4cd2-8652-a7e57028fa83/orig.jpeg',
#    'width': 1800},
#   'id': '91d20ae5-be49-419a-bd8b-457de2064aa3',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/3d3e6f7a-fc87-4ba8-82b8-a909078b4f5f/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '東海大學',
#   'nsfw': False,
#   'postCount': {'last30Days': 603},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 12330,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-09-26T10:23:54.484Z'},
#  {'alias': 'nkfust',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-20T00:15:15.776Z',
#   'description': '高雄第一科大板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/1a31e4b4-3daa-46e7-addd-562d1ee970e5/orig.jpeg',
#    'width': 1800},
#   'id': 'd477f90b-56e4-423d-8686-3524dc331bd5',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/b67f780a-a98d-4f0d-ad79-71563a0d28fe/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '高雄第一科大',
#   'nsfw': False,
#   'postCount': {'last30Days': 100},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 6298,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-09-26T10:23:02.509Z'},
#  {'alias': 'ntust',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-20T01:15:15.778Z',
#   'description': '台科大板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/80ba5305-f90f-4efa-8f5c-ad9837eb5e8f/orig.jpeg',
#    'width': 1800},
#   'id': '7e1a5d67-6085-491b-987a-e8ab6ddbd3ce',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/a3120743-b923-4ade-8417-5ed491d80471/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '台科大',
#   'nsfw': False,
#   'postCount': {'last30Days': 60},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 5537,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-09-26T10:24:27.905Z'},
#  {'alias': 'nchu',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-20T02:15:15.779Z',
#   'description': '中興大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/bee7a5fb-f4c6-48ae-bfe1-6ace87dbc1dc/orig.jpeg',
#    'width': 1800},
#   'id': '9bfaab73-e0d2-4e73-ab82-101ab66dd2d4',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/51f16f78-0cb8-4a15-84f4-67bfb4ec58f7/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '中興大學',
#   'nsfw': False,
#   'postCount': {'last30Days': 172},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 7982,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-09-26T10:24:42.593Z'},
#  {'alias': 'yzu',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-20T03:15:15.781Z',
#   'description': '元智大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/0f91df24-f7c0-4c92-8b83-8d962e4090e3/orig.jpeg',
#    'width': 1800},
#   'id': '5e7919b5-805c-41c7-ad27-332105f9c614',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/8a7ee551-2866-4719-8444-ae7bd322c9fd/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '元智大學',
#   'nsfw': False,
#   'postCount': {'last30Days': 222},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 5105,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-09-26T10:24:37.998Z'},
#  {'alias': 'nuu',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-20T04:15:15.782Z',
#   'description': '聯合大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/b2e09129-2e82-4bbb-ae6f-df410f8702b1/orig.jpeg',
#    'width': 1800},
#   'id': '8b977798-d2b7-4c58-a21f-43c50e802bcf',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/72a16ede-18a5-4129-8c52-d12bde245a51/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '聯合大學',
#   'nsfw': False,
#   'postCount': {'last30Days': 160},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 4133,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-09-26T10:21:03.966Z'},
#  {'alias': 'ntou',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-20T05:15:15.784Z',
#   'description': '海洋大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/e1652401-25ed-496d-89ca-2e0e0611564e/orig.jpeg',
#    'width': 1800},
#   'id': '2cc8a947-691c-43c5-9f22-f323d1be75df',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/d4e57420-b185-4d51-81e8-bcd987851012/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '海洋大學',
#   'nsfw': False,
#   'postCount': {'last30Days': 140},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 4493,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-09-26T10:23:17.618Z'},
#  {'alias': 'nsysu',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-20T06:15:15.785Z',
#   'description': '中山大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/fa56c166-40ad-4b7b-be89-c89f3bf70d9c/orig.jpeg',
#    'width': 1800},
#   'id': 'eb59cc29-b856-4e45-8ff8-4936aeefc122',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/13a7a3c2-40a8-4b57-b230-3035ecff7a96/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '中山大學',
#   'nsfw': False,
#   'postCount': {'last30Days': 107},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 4624,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-10-08T14:27:47.987Z'},
#  {'alias': 'ntpu',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-20T07:15:15.786Z',
#   'description': '臺北大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/f8335431-74ef-49cb-94cd-b44df550774f/orig.jpeg',
#    'width': 1800},
#   'id': '0b8a02a7-98c1-4da9-8c15-b3dea327ec65',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/291d6a9e-69ce-4243-a31a-e60b45184e07/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '臺北大學',
#   'nsfw': False,
#   'postCount': {'last30Days': 233},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 5095,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-09-26T10:21:48.647Z'},
#  {'alias': 'cpu',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-20T08:15:15.788Z',
#   'description': '中央警察大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/1cbcfc71-e6e9-419f-a157-ee676e11499c/orig.jpeg',
#    'width': 1800},
#   'id': 'a69444ff-19f2-4ac4-b5d8-674a18a3b56b',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/0872cd7b-d91c-44a0-a313-062ec88c29b7/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '中央警察大學',
#   'nsfw': False,
#   'postCount': {'last30Days': 29},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 4428,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-09-26T10:25:07.139Z'},
#  {'alias': 'ccu',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-20T09:15:15.789Z',
#   'description': '中正大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/4194bf5b-1fe2-46a2-85a4-8c3fe59212c6/orig.jpeg',
#    'width': 1800},
#   'id': '2883c40b-552b-4b86-87ac-8c3209b88a17',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/ab892df7-78fc-475a-8959-68e8dcfa2f7c/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '中正大學',
#   'nsfw': False,
#   'postCount': {'last30Days': 227},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 6308,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-09-26T10:25:05.190Z'},
#  {'alias': 'usc',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-20T10:15:15.790Z',
#   'description': '實踐大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/02051c8f-af89-4f73-a044-fce6d518bed3/orig.jpeg',
#    'width': 1800},
#   'id': '2d5b4fc9-3eaa-4a8f-9dab-c9a835c2d5fa',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/27c8e3ef-ae4c-485e-aa89-32b3f8783cd9/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '實踐大學',
#   'nsfw': False,
#   'postCount': {'last30Days': 136},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 6053,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-09-26T10:21:58.798Z'},
#  {'alias': 'ym',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-20T11:15:15.792Z',
#   'description': '陽明大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/59b30df7-24ef-4e4b-b42d-bb793b4e0509/orig.jpeg',
#    'width': 1800},
#   'id': '04831d50-5849-4f3c-827c-c9c82dc71d03',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/ce198f79-a4e3-4350-a485-ce9e9154ee69/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '陽明大學',
#   'nsfw': False,
#   'postCount': {'last30Days': 2},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 1496,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-09-26T10:22:16.613Z'},
#  {'alias': 'ntua',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-20T12:15:15.794Z',
#   'description': '臺灣藝術大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/56898242-de5e-4348-82b1-56fbcd1d4b38/orig.jpeg',
#    'width': 1800},
#   'id': '5398dfd6-1a81-4a92-ac8b-e79f2b2093cb',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/784712bd-e3ae-45b2-a30a-846d78d59e27/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '臺灣藝術大學',
#   'nsfw': False,
#   'postCount': {'last30Days': 59},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 3016,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-09-26T10:21:28.709Z'},
#  {'alias': 'shu',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-20T13:15:15.795Z',
#   'description': '世新大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/2d07a127-e849-4925-a12d-93939a1ffc86/orig.jpeg',
#    'width': 1800},
#   'id': '34a50714-d3df-4fc3-9ff0-0d836f35088c',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/a93e0384-649a-44f0-a732-3e487094d121/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '世新大學',
#   'nsfw': False,
#   'postCount': {'last30Days': 265},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 7425,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-09-26T10:24:33.397Z'},
#  {'alias': 'ntue',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-20T14:15:15.797Z',
#   'description': '臺北教育大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/53b73f5f-3488-476e-9436-e27135bf4bc8/orig.jpeg',
#    'width': 1800},
#   'id': '0bd78baa-4dde-49da-b3ec-edf066826f81',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/c5993984-77ff-4265-bedb-1214e90ff7eb/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '臺北教育大學',
#   'nsfw': False,
#   'postCount': {'last30Days': 124},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 1758,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-09-26T10:21:42.809Z'},
#  {'alias': 'tnua',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-20T15:15:15.798Z',
#   'description': '臺北藝術大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/d8586ef9-be83-46c6-be1f-e91e0249e9ee/orig.jpeg',
#    'width': 1800},
#   'id': '7553dd7b-9607-4629-a2b4-d52d0450b059',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/b35838af-7475-46b0-93b2-f358c35daa53/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '臺北藝術大學',
#   'nsfw': False,
#   'postCount': {'last30Days': 40},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': ['課程評價'],
#   'subscribed': False,
#   'subscriptionCount': 2266,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2019-09-26T10:21:39.214Z'},
#  {'alias': 'utaipei',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2016-05-20T16:15:15.800Z',
#   'description': '臺北市立大學板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，舉凡課程資訊、教授教學評價，又或是學校活動，只要是你想要知道的資訊，都能在校板中迅速獲得解答！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/ad7c72f9-7a99-45ab-8294-57b0637654a1/orig.jpeg',
#    'width': 1800},
#   'id': '884ae591-32e8-466c-ad94-784931c590e1',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': True,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/141f4076-8a6a-4e04-9679-a0d450938dbf/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '臺北市立大學',
#   'nsfw': False,
# ...
#   'heroImage': {'height': 414,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/fa4f329f-e9d7-4462-b6d3-f9baca8aab6a/orig.jpeg',
#    'width': 1242},
#   'id': '16d8d779-4aff-4455-93e0-4a6cf3413d19',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'isSchool': False,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/df1b8547-62ea-4c18-8dd6-2a4a53e1b4ce/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '傳說對決',
#   'nsfw': False,
#   'postCount': {'last30Days': 312},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': [],
#   'subscribed': False,
#   'subscriptionCount': 5893,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2020-07-08T01:31:57.378Z'},
#  {'alias': 'lovenproducer',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2020-05-19T05:36:12.826Z',
#   'description': '歡迎大家來到戀與製作人板，希望太太們能在這裡交流，互相交換資訊唷(⁎⁍̴̛ᴗ⁍̴̛⁎)',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 414,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/fb9d463a-195a-4650-b083-57d6b6432ea9/orig.jpeg',
#    'width': 1242},
#   'id': '9acbdf1b-6406-4ddd-9924-8b0ef61e8851',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'isSchool': False,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/f7478759-25a1-453b-a81f-ff58e31ebb36/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '戀與製作人',
#   'nsfw': False,
#   'postCount': {'last30Days': 79},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '記得標註文章分類內容唷 例如：#抽卡',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': [],
#   'subscribed': False,
#   'subscriptionCount': 2723,
#   'titlePlaceholder': '',
#   'topics': ['白起', '李澤言', '許墨', '周棋洛', '抽卡', '陸服'],
#   'updatedAt': '2020-06-02T12:09:11.769Z'},
#  {'alias': 'food_mover',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2020-05-19T05:36:33.432Z',
#   'description': '歡迎來到食物語版～\n希望在這邊可以解決你們的問題❤️',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/97ee2ffb-7a8e-4af7-8380-d646550258b1/orig.jpeg',
#    'width': 1800},
#   'id': '612dd883-8f57-45a1-ac8d-47c706f25e6b',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'isSchool': False,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/949a216a-5241-4eba-bde9-08abc7e24b4c/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '食物語',
#   'nsfw': False,
#   'postCount': {'last30Days': 35},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '需要發文詢問組隊請標上 #求健檢\n有任何新活動請標上 #活動文',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': [],
#   'subscribed': False,
#   'subscriptionCount': 1689,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2020-06-04T10:39:22.106Z'},
#  {'alias': 'maple_story',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2020-05-19T05:36:52.263Z',
#   'description': '發文前記得閱讀板規～祝大家遊戲愉快:D\n發文標題請加上分類！發文標題請加上分類！\n分類項目請看板規 2 有完整範例。\n每週最新活動資訊點置頂文章🔝或話題傳送門',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/e64b14b0-9833-4a37-82b6-7c2a07089a5d/full.jpeg',
#    'width': 1800},
#   'id': '9ee9fe06-9ffa-4169-8910-618e783f862f',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'isSchool': False,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/bebab651-4fe2-4191-83f4-cf1313b4df33/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '楓之谷',
#   'nsfw': False,
#   'postCount': {'last30Days': 120},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '發文前請閱讀板規標題分類～',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': [],
#   'subscribed': False,
#   'subscriptionCount': 3550,
#   'titlePlaceholder': '',
#   'topics': ['黃金蘋果', '時尚隨機箱', '皇家美髮整形', '新楓之谷', '楓之谷', '楓之谷M', '楓谷'],
#   'updatedAt': '2020-06-28T09:05:51.072Z'},
#  {'alias': 'identity_v',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2020-05-19T05:37:14.181Z',
#   'description': '歡迎大家在這個板上一起討論第五這個遊戲～',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 343,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/29a685d7-f4c0-49de-b46e-f787a4eb7033/orig.jpeg',
#    'width': 1029},
#   'id': 'e064be2b-13f8-468a-9e88-b357170a0e33',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'isSchool': False,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 179,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/be582a3b-d843-4cd4-8903-3552f922b7b1/orig.jpeg',
#    'width': 179},
#   'mediaThreshold': {},
#   'name': '第五人格',
#   'nsfw': False,
#   'postCount': {'last30Days': 166},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': [],
#   'subscribed': False,
#   'subscriptionCount': 2163,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2020-06-12T09:34:46.918Z'},
#  {'alias': 'switch',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2020-05-19T05:37:44.144Z',
#   'description': '',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 410,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/9d524427-6bea-424d-be03-d167758b5722/orig.jpeg',
#    'width': 1230},
#   'id': 'ea38435a-1533-4eb0-9c66-76451d31fc35',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'isSchool': False,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/b3ba574c-d9ef-427e-8748-ab439d4f8222/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': 'Nintendo Switch',
#   'nsfw': False,
#   'postCount': {'last30Days': 123},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': [],
#   'subscribed': False,
#   'subscriptionCount': 5283,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2020-06-05T11:12:26.154Z'},
#  {'alias': 'playstation',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2020-05-19T05:38:33.868Z',
#   'description': '歡迎來到PlayStation版，各位可以分享你們玩遊戲的心得，攻略，以及PlayStation的新聞。\n請先詳閱版規，切勿違反呦',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 393,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/5f795fff-a810-4cc5-a568-07cfa92964cb/orig.jpeg',
#    'width': 1181},
#   'id': '332fec2f-7d2c-40f2-b594-cef586c849c5',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'isSchool': False,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/35173eb6-2043-4e37-93ee-c84d85281720/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': 'PlayStation',
#   'nsfw': False,
#   'postCount': {'last30Days': 33},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '請注意⚠️內文須超過十五個中文字元⚠️',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': [],
#   'subscribed': False,
#   'subscriptionCount': 2174,
#   'titlePlaceholder': '',
#   'topics': ['心得', '攻略', 'PS5', 'PS4', '新聞', 'PlayStation'],
#   'updatedAt': '2020-06-13T10:11:48.332Z'},
#  {'alias': 'pc_game',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2020-05-19T05:39:41.737Z',
#   'description': '歡迎大家來找隊友一起打團，排位，分享攻略等等',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/b8286277-19cb-42e2-88ea-e88dd0c4a474/full.jpeg',
#    'width': 1800},
#   'id': 'b5bffbd7-da4f-4591-8323-e763b3accf4d',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'isSchool': False,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/82738950-377d-4886-b2a9-7fc43405ea58/full.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': 'PC Game',
#   'nsfw': False,
#   'postCount': {'last30Days': 54},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': [],
#   'subscribed': False,
#   'subscriptionCount': 2074,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2020-06-04T10:30:18.817Z'},
#  {'alias': '7_deadly_sins',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2020-05-19T06:31:20.260Z',
#   'description': '歡迎七大罪的粉絲們在這裡交流哦！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 500,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/f9b3c16a-be1c-498c-9f20-d7f867c2d1aa/orig.jpeg',
#    'width': 1500},
#   'id': 'd6d6529d-4886-4564-aeb7-e27adc0ae3f0',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'isSchool': False,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/766241ed-5d43-40c2-9613-4b7a3085755b/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '七大罪',
#   'nsfw': False,
#   'postCount': {'last30Days': 5},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': [],
#   'subscribed': False,
#   'subscriptionCount': 584,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2020-06-08T14:50:39.422Z'},
#  {'alias': 'dd52',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2020-05-26T12:48:20.450Z',
#   'description': '',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/fd6555ba-3a16-4c82-a765-d37ef8bfb6df/full.jpeg',
#    'width': 1800},
#   'id': '0acd2601-4462-4bcb-9802-3ca7aacab20c',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'isSchool': False,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/4890ca81-a3d1-44bc-92db-061c75d5b15b/full.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '菱格世代 DD52',
#   'nsfw': False,
#   'postCount': {'last30Days': 107},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': [],
#   'subscribed': False,
#   'subscriptionCount': 2609,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2020-05-28T03:51:30.187Z'},
#  {'alias': 'podcast',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2020-06-08T09:01:58.763Z',
#   'description': 'Podcast 板以討論 Podcast 為主，歡迎分享你喜歡的節目、主持人或者相關資訊，發文前記得先詳閱板規唷！',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/7f0665f2-ee68-4ffe-acf5-88a48626897a/full.jpeg',
#    'width': 1800},
#   'id': 'e6e73722-dade-42c8-971f-16253c1b7a7c',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'isSchool': False,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/e8df17a5-f76f-40ee-89e8-74fc18e4a25d/full.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': 'Podcast',
#   'nsfw': False,
#   'postCount': {'last30Days': 41},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': [],
#   'subscribed': False,
#   'subscriptionCount': 4139,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2020-06-17T08:21:32.224Z'},
#  {'alias': 'funny_video',
#   'availableLayouts': ['video'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2020-06-09T10:48:52.539Z',
#   'description': '梗圖=有梗的圖，梗影=有梗的影片',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 285,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/48f4f123-7cfa-42ed-95ff-417243d88b61/orig.jpeg',
#    'width': 856},
#   'id': '99602190-dde4-4ba0-82da-068d65bbe2ff',
#   'ignorePost': True,
#   'invisible': False,
#   'ipCountryCondition': {'exclude': [], 'include': []},
#   'isSchool': False,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/b3e0cc07-5358-4b31-a26e-ec5bb86b4cab/orig.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': '梗影',
#   'nsfw': False,
#   'postCount': {'last30Days': 50},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': [],
#   'subscribed': False,
#   'subscriptionCount': 1555,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2020-06-19T07:53:35.869Z'},
#  {'alias': 'line_fresh',
#   'availableLayouts': ['classic'],
#   'canPost': False,
#   'canUseNickname': True,
#   'createdAt': '2020-06-30T04:09:20.357Z',
#   'description': '',
#   'favorite': False,
#   'fullyAnonymous': False,
#   'hasPostCategories': False,
#   'heroImage': {'height': 600,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/d980eaad-5a11-4302-b36d-e73b23d5ca7c/full.jpeg',
#    'width': 1800},
#   'id': 'e2602a00-3f9a-435e-98a2-457ff4da77fc',
#   'ignorePost': False,
#   'invisible': False,
#   'ipCountryCondition': {},
#   'isSchool': False,
#   'limitCountries': [],
#   'limitStage': 0,
#   'logo': {'height': 200,
#    'type': 'image/jpeg',
#    'url': 'https://megapx-assets.dcard.tw/images/54b42ca7-32d3-498e-94b7-d163862c90cd/full.jpeg',
#    'width': 200},
#   'mediaThreshold': {},
#   'name': 'LINE FRESH 校園競賽',
#   'nsfw': False,
#   'postCount': {'last30Days': 8},
#   'postThumbnail': {'size': 'small'},
#   'postTitlePlaceholder': '',
#   'read': False,
#   'shouldCategorized': False,
#   'shouldPostCategorized': False,
#   'subcategories': [],
#   'subscribed': False,
#   'subscriptionCount': 102,
#   'titlePlaceholder': '',
#   'topics': [],
#   'updatedAt': '2020-06-30T04:12:16.105Z'}]
