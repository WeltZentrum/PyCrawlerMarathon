# %% [markdown]
# # 反爬：登入授權模擬
#
# * 了解「登入權限機制」的反爬蟲機制
# * 「登入權限機制」反爬蟲的因應策略

# %% [markdown]
# ## 未授權前存取

# %%
import requests
from bs4 import BeautifulSoup

# %%
res = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html', verify = False)
soup = BeautifulSoup(res.text, 'html.parser')
print(soup.text)
# Out:
# D:\AppData\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# D:\AppData\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 本網站已依網站內容分級規定處理
# 警告︰您即將進入之看板內容需滿十八歲方可瀏覽。
# 若您尚未年滿十八歲，請點選離開。若您已滿十八歲，亦不可將本區之內容派發、傳閱、出售、出租、交給或借予年齡未滿18歲的人士瀏覽，或將本網站內容向該人士出示、播放或放映。
#
#
#
#
#
#
# 我同意，我已年滿十八歲進入
#
#
# 未滿十八歲或不同意本條款離開

# %% [markdown]
# ## 模仿授權機制

# %% [markdown]
# ### 方法一：先送登入，再送請求

# %%
rs = requests.session()
payload={
    'from':'/bbs/Gossiping/index.html',
    'yes': 'yes'
}
res = rs.post('https://www.ptt.cc/ask/over18',verify = False, data = payload)
res = rs.get('https://www.ptt.cc/bbs/Gossiping/index.html',verify = False)
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# D:\AppData\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# D:\AppData\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# D:\AppData\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# 看板 Gossiping 文章列表 - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 Gossiping
# 關於我們
# 聯絡資訊
#
#
#
#
#
#
# 看板
# 精華區
#
#
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
#
#
#
#
#
#
#
#
#
#
# 6
#
# Re: [新聞] 丹丹已不賣皮蛋瘦肉粥 陳其邁酸李眉蓁和
#
#
# Scathach
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Scathach 的文章
#
#
#  7/15
#
#
#
#
#
#
# [新聞] 麥寮六輕大火 彰化大城測站PM10一度飆升
#
#
# ams9
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ams9 的文章
#
#
#  7/15
#
#
#
#
# 3
#
# Re: [問卦] 為何一堆水電師傅不裝TOTO馬桶？
#
#
# wildmeteor
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 wildmeteor 的文章
#
#
#  7/15
#
#
#
#
# 1
#
# [問卦] 有法醫蕭開平的八卦嗎?
#
#
# allenblack
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 allenblack 的文章
#
#
#  7/15
#
#
#
#
#
#
# [問卦] 獵人三基佬
#
#
# Hosh
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Hosh 的文章
#
#
#  7/15
#
#
#
#
# 27
#
# [問卦] 蘇貞昌你給我來ibon排隊喔
#
#
# lapdada
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 lapdada 的文章
#
#
#  7/15
#
#
#
#
# 10
#
# [問卦] 有研究所學歷後大學學歷還重要嗎？
#
#
# bencert
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 bencert 的文章
#
#
#  7/15
#
#
#
#
# 13
#
# [新聞] 熊貓又有新招！稱「重複下單」好心幫取
#
#
# DaAnnabelle
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 DaAnnabelle 的文章
#
#
#  7/15
#
#
#
#
# 1
#
# [問卦] 台北哪個夜市三倍券最好花?
#
#
# bluebugi
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 bluebugi 的文章
#
#
#  7/15
#
#
#
#
# 1
#
# [問卦] 小穹的新漫畫>///< (小穹陣線)
#
#
# EmeraldAZ
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 EmeraldAZ 的文章
#
#
#  7/15
#
#
#
#
#
#
# [問卦] 統神會怎樣用三倍卷?
#
#
# ruby00514
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ruby00514 的文章
#
#
#  7/15
#
#
#
#
# 4
#
# [問卦] 桃太郎帶馬鷹狗去打鬼會怎樣
#
#
# chadmu
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 chadmu 的文章
#
#
#  7/15
#
#
#
#
#
#
# [問卦] 檢舉達人吃飽太閒？ 轎車駕駛臨停不到1分鐘竟被偷拍檢舉
#
#
# kiyoe
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 kiyoe 的文章
#
#
#  7/15
#
#
#
#
#
#
# [問卦] 貓貓折手坐是什麼意思?
#
#
# algebraic
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 algebraic 的文章
#
#
#  7/15
#
#
#
#
# 4
#
# [問卦] 在場還有誰能比我菜?
#
#
# imveryscared
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 imveryscared 的文章
#
#
#  7/15
#
#
#
#
#
#
# Re: [問卦] 我爸去領振興卷到現在還沒回家該報警嗎?
#
#
# cloud72426
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 cloud72426 的文章
#
#
#  7/15
#
#
#
#
#
#
# [問卦] 好想出國玩!
#
#
# yoyodiy
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 yoyodiy 的文章
#
#
#  7/15
#
#
#
#
# 3
#
# Re: [新聞] 蘇貞昌女兒獲政院標案 羅智強批家天下
#
#
# t21
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 t21 的文章
#
#
#  7/15
#
#
#
#
# 3
#
# [問卦] 女同事說我看起來就是回家假日都在家裡
#
#
# aabbcc520
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 aabbcc520 的文章
#
#
#  7/15
#
#
#
#
# 10
#
# [問卦] 時間暫停的超能力有弱點嗎？
#
#
# ThePeaceMan
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ThePeaceMan 的文章
#
#
#  7/15
#
#
#
#
#
#
#
# [公告] 八卦板板規(2020.06.11)
#
#
# seabox
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 seabox 的文章
#
#
#  6/11
# !
#
#
#
# 94
#
# [協尋] 桃園後湖住家附近走失老婦人
#
#
# jpjun
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 jpjun 的文章
#
#
#  6/26
#
#
#
#
# 15
#
# [協尋] 行車記錄器 7/2(四) 早上7:30昌平路四段
#
#
# jjjsai
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 jjjsai 的文章
#
#
#  7/06
#
#
#
#
# 11
#
# [協尋] 行車紀錄器 7/7(二) 彰化林森西路環河街口
#
#
# babygoat
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 babygoat 的文章
#
#
#  7/14
#
#
#
#
# 3
#
# [公告] 數條板規修改草案於gossippicket討論
#
#
# seabox
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 seabox 的文章
#
#
#  7/14
# M
#
#
#
# 本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。

# %% [markdown]
# ### 方法二：在請求中帶入 cookie

# %%
res = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html',verify = False, cookies={'over18': '1'})
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# D:\AppData\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# 看板 Gossiping 文章列表 - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 Gossiping
# 關於我們
# 聯絡資訊
#
#
#
#
#
#
# 看板
# 精華區
#
#
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
#
#
#
#
#
#
#
#
#
#
# 6
#
# Re: [新聞] 丹丹已不賣皮蛋瘦肉粥 陳其邁酸李眉蓁和
#
#
# Scathach
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Scathach 的文章
#
#
#  7/15
#
#
#
#
#
#
# [新聞] 麥寮六輕大火 彰化大城測站PM10一度飆升
#
#
# ams9
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ams9 的文章
#
#
#  7/15
#
#
#
#
# 3
#
# Re: [問卦] 為何一堆水電師傅不裝TOTO馬桶？
#
#
# wildmeteor
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 wildmeteor 的文章
#
#
#  7/15
#
#
#
#
# 1
#
# [問卦] 有法醫蕭開平的八卦嗎?
#
#
# allenblack
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 allenblack 的文章
#
#
#  7/15
#
#
#
#
#
#
# [問卦] 獵人三基佬
#
#
# Hosh
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Hosh 的文章
#
#
#  7/15
#
#
#
#
# 27
#
# [問卦] 蘇貞昌你給我來ibon排隊喔
#
#
# lapdada
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 lapdada 的文章
#
#
#  7/15
#
#
#
#
# 10
#
# [問卦] 有研究所學歷後大學學歷還重要嗎？
#
#
# bencert
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 bencert 的文章
#
#
#  7/15
#
#
#
#
# 13
#
# [新聞] 熊貓又有新招！稱「重複下單」好心幫取
#
#
# DaAnnabelle
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 DaAnnabelle 的文章
#
#
#  7/15
#
#
#
#
# 1
#
# [問卦] 台北哪個夜市三倍券最好花?
#
#
# bluebugi
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 bluebugi 的文章
#
#
#  7/15
#
#
#
#
# 1
#
# [問卦] 小穹的新漫畫>///< (小穹陣線)
#
#
# EmeraldAZ
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 EmeraldAZ 的文章
#
#
#  7/15
#
#
#
#
#
#
# [問卦] 統神會怎樣用三倍卷?
#
#
# ruby00514
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ruby00514 的文章
#
#
#  7/15
#
#
#
#
# 4
#
# [問卦] 桃太郎帶馬鷹狗去打鬼會怎樣
#
#
# chadmu
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 chadmu 的文章
#
#
#  7/15
#
#
#
#
#
#
# [問卦] 檢舉達人吃飽太閒？ 轎車駕駛臨停不到1分鐘竟被偷拍檢舉
#
#
# kiyoe
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 kiyoe 的文章
#
#
#  7/15
#
#
#
#
#
#
# [問卦] 貓貓折手坐是什麼意思?
#
#
# algebraic
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 algebraic 的文章
#
#
#  7/15
#
#
#
#
# 4
#
# [問卦] 在場還有誰能比我菜?
#
#
# imveryscared
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 imveryscared 的文章
#
#
#  7/15
#
#
#
#
#
#
# Re: [問卦] 我爸去領振興卷到現在還沒回家該報警嗎?
#
#
# cloud72426
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 cloud72426 的文章
#
#
#  7/15
#
#
#
#
#
#
# [問卦] 好想出國玩!
#
#
# yoyodiy
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 yoyodiy 的文章
#
#
#  7/15
#
#
#
#
# 3
#
# Re: [新聞] 蘇貞昌女兒獲政院標案 羅智強批家天下
#
#
# t21
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 t21 的文章
#
#
#  7/15
#
#
#
#
# 3
#
# [問卦] 女同事說我看起來就是回家假日都在家裡
#
#
# aabbcc520
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 aabbcc520 的文章
#
#
#  7/15
#
#
#
#
# 10
#
# [問卦] 時間暫停的超能力有弱點嗎？
#
#
# ThePeaceMan
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ThePeaceMan 的文章
#
#
#  7/15
#
#
#
#
#
#
#
# [公告] 八卦板板規(2020.06.11)
#
#
# seabox
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 seabox 的文章
#
#
#  6/11
# !
#
#
#
# 94
#
# [協尋] 桃園後湖住家附近走失老婦人
#
#
# jpjun
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 jpjun 的文章
#
#
#  6/26
#
#
#
#
# 15
#
# [協尋] 行車記錄器 7/2(四) 早上7:30昌平路四段
#
#
# jjjsai
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 jjjsai 的文章
#
#
#  7/06
#
#
#
#
# 11
#
# [協尋] 行車紀錄器 7/7(二) 彰化林森西路環河街口
#
#
# babygoat
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 babygoat 的文章
#
#
#  7/14
#
#
#
#
# 3
#
# [公告] 數條板規修改草案於gossippicket討論
#
#
# seabox
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 seabox 的文章
#
#
#  7/14
# M
#
#
#
# 本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。

# %% [markdown]
# ## 作業目標
#
# * 找一個需要登入的網站試試看，並說明思考流程
# （如果不知道要用哪個網站的話，可以試試看 https://github.com/new 網址，未登入時會被導向登入頁）
